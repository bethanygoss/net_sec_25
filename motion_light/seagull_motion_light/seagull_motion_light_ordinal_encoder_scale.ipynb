# %% [markdown]
# # Finding optimal hyper parameters for a CNN model
#
# The point of this notebook is to obtain an optimal set of parameters for our CNN model to process time based series data. Specifically, we are processing IoT data from TON a well-kept dataset from The UNSW Group in Canberra, Australia.
#
# The specific dataset being discussed here is the IoT Motion Light dataset.

# %% [markdown]
# We have pip install mealpy each time because it is not a default python package ,and every time the runtime refreshes; the package is uninstalled.

# %%
# %pip install mealpy==3.0.1
# %pip install tensorflow
# %pip install -U scikit-learn
# %pip install imbalanced-learn
# %pip install matplotlib
# Out:
# Requirement already satisfied: mealpy==3.0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from mealpy==3.0.1) (2.1.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from mealpy==3.0.1) (3.10.1)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from mealpy==3.0.1) (1.15.2)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from mealpy==3.0.1) (2.2.3)
# Requirement already satisfied: opfunu>=1.0.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from mealpy==3.0.1) (1.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\onius\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\onius\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->mealpy==3.0.1) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from opfunu>=1.0.0->mealpy==3.0.1) (2.32.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2.0->mealpy==3.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2.0->mealpy==3.0.1) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\onius\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy==3.0.1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy==3.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy==3.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy==3.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy==3.0.1) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\onius\appdata\roaming\python\python311\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\onius\appdata\roaming\python\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\onius\appdata\roaming\python\python311\site-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\onius\appdata\roaming\python\python311\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imbalanced-learn in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from imbalanced-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\onius\appdata\roaming\python\python311\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\onius\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\onius\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\onius\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Our main libraries used are:
#
# *   Imblearn
# *   Pandas
# *   Matplot Lib
# *   MealPy
# *   Numpy
# *   SKLearn
# *   Tensorflow
# *   Time

# %%
import pandas
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, StandardScaler
from imblearn.combine import SMOTETomek
import numpy
from sklearn.metrics import classification_report, confusion_matrix,ConfusionMatrixDisplay
import tensorflow
from tensorflow import keras
import matplotlib.pyplot as plt
from mealpy import FloatVar, SOA
import time

# %% [markdown]
# # Preparing the Datasets for the CNN Model
#
# We split off the information that indicates whether or not an attack has occured (*label*) and the types of attacks (*type*).
# Now there are three dataframes:
#   X - all features
#   y - attack or not
#   y_type - type of attack
#
# We split again into test and train data sets and include some randomness.
# **Reset_index** drops the indexes from these new dataframes.
# Next, we encode the text data, add another randomness, and scale all dataframes. The X dataframe is reshaped.

# %%
#Uncomment for local use
#raw_data = pandas.read_csv('../../Train_Test_IoT_dataset/Train_Test_IoT_Motion_Light.csv')
#Uncomment for Google Colab
raw_data = pandas.read_csv('Train_Test_IoT_Motion_Light.csv')
X = raw_data.drop(columns=['label','type'])
y = raw_data['label']
y_type = raw_data['type']

# %%
# Binary
X_train, X_testsplit, y_train, y_testsplit = train_test_split(X, y, test_size=0.2, random_state=777)
# Binary validation
X_test, X_validation, y_test, y_validation = train_test_split(X_testsplit, y_testsplit, test_size=0.5, random_state=777)

#drop index
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
X_validation = X_validation.reset_index(drop=True)
y_validation = y_validation.reset_index(drop=True)

# %%
encoder = OrdinalEncoder()
label_encoder = LabelEncoder()
X_train_encode = encoder.fit_transform(X_train)
X_test_encode = encoder.fit_transform(X_test)
y_train_encode = label_encoder.fit_transform(y_train)
y_test_encode = label_encoder.fit_transform(y_test)
X_validation_encode = encoder.fit_transform(X_validation)
y_validation_encode = label_encoder.fit_transform(y_validation)

# %%
smotetomek = SMOTETomek(random_state=777)
X_rebalance, y_rebalance = smotetomek.fit_resample(X_train_encode, y_train_encode)

# %%
scaler = StandardScaler()
X_rebalance = scaler.fit_transform(X_rebalance)
X_test_encode = scaler.transform(X_test_encode)

X_validation_encode = scaler.transform(X_validation_encode)

# %%
X_rebalance = X_rebalance.reshape(X_rebalance.shape[0], X_rebalance.shape[1], 1)
X_test_encode = X_test_encode.reshape(X_test_encode.shape[0], X_test_encode.shape[1], 1)

X_validation_encode = X_validation_encode.reshape(X_validation_encode.shape[0], X_validation_encode.shape[1], 1)

# %%
start_time_1 = time.perf_counter()
# with tensorflow.device('/device:GPU:0'):
# CNN model detection
# https://keras.io/api/layers/activations/#softmax-function
detection_model = tensorflow.keras.Sequential([
    tensorflow.keras.layers.Input(shape=(X_rebalance.shape[1],X_rebalance.shape[2])),
    tensorflow.keras.layers.Conv1D(filters=50, kernel_size=3, activation='sigmoid'),
    tensorflow.keras.layers.MaxPooling1D(pool_size=2),
    tensorflow.keras.layers.Dropout(0.3),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.LSTM(64),
    tensorflow.keras.layers.Flatten(),
    # 1 layer
    tensorflow.keras.layers.Dense(512, activation='relu'),
    tensorflow.keras.layers.Dropout(0.5),
    # either attack or normal
    tensorflow.keras.layers.Dense(1, activation='sigmoid')
])
detection_model.summary()
# https://keras.io/api/losses/probabilistic_losses/#probabilistic-losses
sgd = tensorflow.keras.optimizers.SGD(learning_rate=0.001)
detection_model.compile(optimizer=sgd,
              loss=tensorflow.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy'])
history = detection_model.fit(X_rebalance, y_rebalance, batch_size=64, epochs=70, validation_data=(X_validation_encode, y_validation_encode))
test_loss, test_acc = detection_model.evaluate(X_test_encode, y_test_encode)

# Make predictions
prediction = detection_model.predict(X_test_encode)
print(prediction)
attack_prediction = numpy.where(prediction > 0.5, 1, 0)
print(attack_prediction)
print(y_test)

# Evaluate the model
print(f"Test Loss: {test_loss}, Test Accuracy: {test_acc}\n")
# https://www.tensorflow.org/tutorials/keras/text_classification for training and validation loss and accuracy
history_dict = history.history
# print(history_dict.keys())
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
print("\n")

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

print("\nClassification Report")
print(classification_report(y_test, attack_prediction))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, attack_prediction))
ConfusionMatrixDisplay.from_predictions(y_test, attack_prediction)
plt.show()

end_time1 = time.perf_counter()
print(f"Time taken: {end_time1 - start_time_1:0.4f} seconds")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 2, 50)          │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 1, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1, 50)          │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        33,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,633 (248.57 KB)
#  Trainable params: 63,533 (248.18 KB)
#  Non-trainable params: 100 (400.00 B)
# Epoch 1/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4964 - loss: 0.6941 - val_accuracy: 0.6366 - val_loss: 0.6926
# Epoch 2/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4989 - loss: 0.6944 - val_accuracy: 0.6186 - val_loss: 0.6909
# Epoch 3/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5037 - loss: 0.6938 - val_accuracy: 0.6186 - val_loss: 0.6899
# Epoch 4/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5012 - loss: 0.6938 - val_accuracy: 0.6186 - val_loss: 0.6892
# Epoch 5/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5025 - loss: 0.6935 - val_accuracy: 0.6186 - val_loss: 0.6886
# Epoch 6/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5001 - loss: 0.6939 - val_accuracy: 0.6186 - val_loss: 0.6881
# Epoch 7/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5023 - loss: 0.6937 - val_accuracy: 0.6186 - val_loss: 0.6878
# Epoch 8/70
# 615/615 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.

# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3944    0
# 3945    1
# 3946    0
# 3947    1
# 3948    0
# Name: label, Length: 3949, dtype: int64
# Test Loss: 0.6850534677505493, Test Accuracy: 0.6059762239456177
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1556
#            1       0.61      1.00      0.75      2393
#
#     accuracy                           0.61      3949
#    macro avg       0.30      0.50      0.38      3949
# weighted avg       0.37      0.61      0.46      3949
#
#
# Confusion Matrix
# [[   0 1556]
#  [   0 2393]]
# c:\Users\onius\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\onius\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\onius\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Time taken: 85.4635 seconds

# %% [markdown]
# # Optimizing the model
# Instead of looking at random number ranges for learning rates, filters, and hidden units, we have encoded specific values.
#
# The hyper parameters we are attempting to optimize are:
#
# *   Batch Size
# *   Activation Functions
# *   Learning Rates
# *   Filters
# *   Hidden Units
#
# The base CNN model we made is ingested into *objective_function*.
#   This is where our hyper parameters are being considered.
#   It returns the Accuracy of that particular iteration.
# **LB** and **UB** is set according to the list given above.

# %%
BATCH_ENCODER = LabelEncoder()
BATCH_ENCODER.fit([32, 64, 128])

#act encoder --> Which activation function should be used?
ACT_ENCODER = LabelEncoder()
ACT_ENCODER.fit(['softmax', 'softplus', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear'])

#Learning Rate encoder
LR_ENCODER = LabelEncoder()
LR_ENCODER.fit([0.0005, 0.001, 0.005, 0.01, 0.05, 0.1])


#Filter encoder
FILTER_ENCODER = LabelEncoder()
FILTER_ENCODER.fit([25, 50, 75])

#Hidden Units encoder
HIDDEN_ENCODER = LabelEncoder()
HIDDEN_ENCODER.fit([400, 512, 640])

#Dense Layer encoder
DENSE_ENCODER = LabelEncoder()
DENSE_ENCODER.fit([5, 8, 10])

def objective_function(params):
  '''RULES:
      Batch Size - 32, 64, 128
      Activation - softmax, softplus, relu, tanh, sigmoid, hard_sigmoid, linear
      Learning Rate - 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1
      Filters - 25, 50, 75
      Hidden Units - 400, 512, 640
      Dense Layers - 5, 8, 10
  '''
  batch_size = BATCH_ENCODER.inverse_transform([int(params[0])])[0]
  activation = ACT_ENCODER.inverse_transform([int(params[1])])[0]
  learning_rate = LR_ENCODER.inverse_transform([int(params[2])])[0]
  filter = FILTER_ENCODER.inverse_transform([int(params[3])])[0]
  hidden_units = HIDDEN_ENCODER.inverse_transform([int(params[4])])[0]
  #dense_layers = DENSE_ENCODER.inverse_transform([int(params[5])])[0]
  model = tensorflow.keras.Sequential()
  model.add(tensorflow.keras.layers.Input(shape=(X_rebalance.shape[1], X_rebalance.shape[2]))),
  model.add(tensorflow.keras.layers.Conv1D(filters=filter, kernel_size=3, activation='sigmoid')),
  model.add(tensorflow.keras.layers.MaxPooling1D(pool_size=2)),
  model.add(tensorflow.keras.layers.Dropout(0.3)),
  model.add(tensorflow.keras.layers.BatchNormalization()),
  model.add(tensorflow.keras.layers.LSTM(64)),
  model.add(tensorflow.keras.layers.Flatten()),
  model.add(tensorflow.keras.layers.Dense(int(hidden_units), activation=activation)),
  model.add(tensorflow.keras.layers.Dropout(0.5)),
  model.add(tensorflow.keras.layers.Dense(1, activation='sigmoid'))

  optimizer = tensorflow.keras.optimizers.SGD(learning_rate=learning_rate)
  model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

  history = model.fit(X_rebalance, y_rebalance, batch_size=batch_size, epochs=15, validation_data=(X_validation_encode, y_validation_encode), verbose=0)
  min_validation_accuracy = 1-history.history['val_accuracy'][-1]
  print(f"Accuracy {min_validation_accuracy}")
  return min_validation_accuracy

LB = [0, 0, 0, 0, 0]

UB = [2.99, 6.99, 5.99, 2.99, 2.99]

problem_dict = {
    "obj_func": objective_function,
    "bounds": FloatVar(lb=LB, ub=UB),
    "minmax": "min",
    "verbose": True
}

model = SOA.OriginalSOA(epoch=15, pop_size=20, fc=2)
g_best = model.solve(problem_dict)
print(f"Solution: {g_best.solution}, Fitness: {g_best.target.fitness}")
print(f"Solution: {model.g_best.solution}, Fitness: {model.g_best.target.fitness}")
model.history.save_global_objectives_chart(filename="seagull-thermo/goc")
model.history.save_local_objectives_chart(filename="seagull-thermo/loc")

model.history.save_global_best_fitness_chart(filename="seagull-thermo/gbfc")
model.history.save_local_best_fitness_chart(filename="seagull-thermo/lbfc")

model.history.save_runtime_chart(filename="seagull-thermo/rtc")

model.history.save_exploration_exploitation_chart(filename="seagull-thermo/eec")

model.history.save_diversity_chart(filename="seagull-thermo/dc")
# Out:
# 2025/04/14 08:43:48 PM, INFO, mealpy.bio_based.SOA.OriginalSOA: Solving single objective optimization problem.
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.47961509227752686
# Accuracy 0.3198277950286865
# Accuracy 0.3813623785972595
# Accuracy 0.5343124866485596
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.26867562532424927
# Accuracy 0.4872119426727295
# Accuracy 0.32843756675720215
# Accuracy 0.31957459449768066
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.4872119426727295
# Accuracy 0.415801465511322
# Accuracy 0.6186376214027405
# Accuracy 0.6062294244766235
# Accuracy 0.24613827466964722
# Accuracy 0.3813623785972595
# Accuracy 0.24613827466964722
# Accuracy 0.2562674283981323
# Accuracy 0.6186376214027405
# Accuracy 0.3654089570045471
# Accuracy 0.3813623785972595
# 2025/04/14 08:59:52 PM, INFO, mealpy.bio_based.SOA.OriginalSOA: >>>Problem: P, Epoch: 1, Current best: 0.24613827466964722, Global best: 0.24613827466964722, Runtime: 451.71689 seconds
# Accuracy 0.3813623785972595
# Accuracy 0.2681691646575928
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.37528491020202637
# Accuracy 0.4872119426727295
# Accuracy 0.37300580739974976
# Accuracy 0.24613827466964722
# Accuracy 0.3813623785972595
# Accuracy 0.2826032042503357
# Accuracy 0.6634590923786163
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.6009116172790527
# Accuracy 0.3813623785972595
# Accuracy 0.3813623785972595
# Accuracy 0.4770827889442444
# Accuracy 0.24613827466964722
# 2025/04/14 09:07:30 PM, INFO, mealpy.bio_based.SOA.OriginalSOA: >>>Problem: P, Epoch: 2, Current best: 0.24613827466964722, Global best: 0.24613827466964722, Runtime: 458.75487 seconds
# Accuracy 0.3813623785972595
# Accuracy 0.32843756675720215
# Accuracy 0.6654849350452423
# Accuracy 0.24613827466964722
# Accuracy 0.3813623785972595
# Accuracy 0.37984299659729004
# Accuracy 0.3998480439186096
# Accuracy 0.5864775776863098
# Accuracy 0.4722714424133301
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.2826032042503357
# Accuracy 0.678652822971344
# Accuracy 0.44922763109207153
# Accuracy 0.678652822971344
# Accuracy 0.6062294244766235
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.32843756675720215
# Accuracy 0.6186376214027405
# 2025/04/14 09:14:10 PM, INFO, mealpy.bio_based.SOA.OriginalSOA: >>>Problem: P, Epoch: 3, Current best: 0.24613827466964722, Global best: 0.24613827466964722, Runtime: 399.83278 seconds
# Accuracy 0.3998480439186096
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.6062294244766235
# Accuracy 0.4760698676109314
# Accuracy 0.4872119426727295
# Accuracy 0.6062294244766235
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.3076728582382202
# Accuracy 0.33426183462142944
# Accuracy 0.32843756675720215
# Accuracy 0.24613827466964722
# Accuracy 0.32843756675720215
# Accuracy 0.3813623785972595
# Accuracy 0.32843756675720215
# 2025/04/14 09:21:08 PM, INFO, mealpy.bio_based.SOA.OriginalSOA: >>>Problem: P, Epoch: 4, Current best: 0.24613827466964722, Global best: 0.24613827466964722, Runtime: 417.98808 seconds
# Accuracy 0.4872119426727295
# Accuracy 0.36464929580688477
# Accuracy 0.6186376214027405
# Accuracy 0.3076728582382202
# Accuracy 0.6186376214027405
# Accuracy 0.3329957127571106
# Accuracy 0.6186376214027405
# Accuracy 0.6186376214027405
# Accuracy 0.4872119426727295
# Accuracy 0.261838436126709
# Accuracy 0.6186376214027405
# Accuracy 0.3813623785972595
# Accuracy 0.24613827466964722
# Accuracy 0.3076728582382202
# Accuracy 0.3813623785972595
# Accuracy 0.6186376214027405
# Accuracy 0
# with tensorflow.device('/device:GPU:0'):
# CNN model detection
# https://keras.io/api/layers/activations/#softmax-function
detection_model = tensorflow.keras.Sequential([
    tensorflow.keras.layers.Input(shape=(X_rebalance.shape[1],X_rebalance.shape[2])),
    tensorflow.keras.layers.Conv1D(filters=75, kernel_size=3, activation='sigmoid'),
    tensorflow.keras.layers.MaxPooling1D(pool_size=2),
    tensorflow.keras.layers.Dropout(0.3),
    tensorflow.keras.layers.BatchNormalization(),
    tensorflow.keras.layers.LSTM(64),
    tensorflow.keras.layers.Flatten(),
    # 1 layer
    tensorflow.keras.layers.Dense(640, activation='linear'),
    tensorflow.keras.layers.Dropout(0.5),
    # either attack or normal
    tensorflow.keras.layers.Dense(1, activation='sigmoid')
])
detection_model.summary()
# https://keras.io/api/losses/probabilistic_losses/#probabilistic-losses
sgd = tensorflow.keras.optimizers.SGD(learning_rate=0.1)
detection_model.compile(optimizer=sgd,
              loss=tensorflow.keras.losses.BinaryCrossentropy(from_logits=False),
              metrics=['accuracy'])
history = detection_model.fit(X_rebalance, y_rebalance, batch_size=128, epochs=70, validation_data=(X_validation_encode, y_validation_encode))
test_loss, test_acc = detection_model.evaluate(X_test_encode, y_test_encode)

# Make predictions
prediction = detection_model.predict(X_test_encode)
print(prediction)
attack_prediction = numpy.where(prediction > 0.5, 1, 0)
print(attack_prediction)
print(y_test)

# Evaluate the model
print(f"Test Loss: {test_loss}, Test Accuracy: {test_acc}\n")
# https://www.tensorflow.org/tutorials/keras/text_classification for training and validation loss and accuracy
history_dict = history.history
# print(history_dict.keys())
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
print("\n")

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

print("\nClassification Report")
print(classification_report(y_test, attack_prediction))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, attack_prediction))
ConfusionMatrixDisplay.from_predictions(y_test, attack_prediction)
plt.show()

end_time2 = time.perf_counter()
print(f"Time taken: {end_time2 - start_time_2:0.4f} seconds")
# Out:
# Model: "sequential_323"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_323 (Conv1D)             │ (None, 2, 75)          │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_323               │ (None, 1, 75)          │             0 │
# │ (MaxPooling1D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_646 (Dropout)           │ (None, 1, 75)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_323         │ (None, 1, 75)          │           300 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_323 (LSTM)                 │ (None, 64)             │        35,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_323 (Flatten)           │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_646 (Dense)               │ (None, 640)            │        41,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_647 (Dropout)           │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_647 (Dense)               │ (None, 1)              │           641 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 78,681 (307.35 KB)
#  Trainable params: 78,531 (306.76 KB)
#  Non-trainable params: 150 (600.00 B)
# Epoch 1/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5001 - loss: 0.6948 - val_accuracy: 0.3814 - val_loss: 0.6973
# Epoch 2/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5225 - loss: 0.6913 - val_accuracy: 0.6186 - val_loss: 0.6820
# Epoch 3/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5518 - loss: 0.6846 - val_accuracy: 0.6186 - val_loss: 0.6707
# Epoch 4/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5983 - loss: 0.6687 - val_accuracy: 0.6186 - val_loss: 0.6755
# Epoch 5/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6278 - loss: 0.6497 - val_accuracy: 0.6186 - val_loss: 0.6886
# Epoch 6/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6579 - loss: 0.6172 - val_accuracy: 0.6186 - val_loss: 0.7204
# Epoch 7/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7011 - loss: 0.5619 - val_accuracy: 0.5685 - val_loss: 0.8899
# Epoch 8/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7790 - loss: 0.4750 - val_accuracy: 0.3434 - val_loss: 1.3605
# Epoch 9/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9934 - loss: 0.0201 - val_accuracy: 0.6802 - val_loss: 5.5753
# Epoch 44/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9899 - loss: 0.0340 - val_accuracy: 0.5128 - val_loss: 6.6194
# Epoch 45/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9877 - loss: 0.0370 - val_accuracy: 0.7260 - val_loss: 5.5817
# Epoch 46/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9872 - loss: 0.0457 - val_accuracy: 0.6419 - val_loss: 6.1757
# Epoch 47/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9901 - loss: 0.0311 - val_accuracy: 0.6445 - val_loss: 6.7106
# Epoch 48/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0427 - val_accuracy: 0.7045 - val_loss: 6.5008
# Epoch 49/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9938 - loss: 0.0178 - val_accuracy: 0.4778 - val_loss: 6.6128
# Epoch 50/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0368 - val_accuracy: 0.7045 - val_loss: 7.0394
# Epoch 51/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9928 - loss: 0.0241 - val_accuracy: 0.7045 - val_loss: 7.2585
# Epoch 52/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9953 - loss: 0.0147 - val_accuracy: 0.7045 - val_loss: 7.3023
# Epoch 53/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9955 - loss: 0.0141 - val_accuracy: 0.6802 - val_loss: 7.0859
# Epoch 54/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9928 - loss: 0.0248 - val_accuracy: 0.7045 - val_loss: 7.3551
# Epoch 55/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0122 - val_accuracy: 0.6802 - val_loss: 3.1167
# Epoch 56/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9843 - loss: 0.0518 - val_accuracy: 0.6870 - val_loss: 4.1484
# Epoch 57/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9955 - loss: 0.0146 - val_accuracy: 0.6802 - val_loss: 4.4148
# Epoch 58/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9959 - loss: 0.0127 - val_accuracy: 0.6473 - val_loss: 2.4135
# Epoch 59/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9887 - loss: 0.0358 - val_accuracy: 0.5662 - val_loss: 3.4518
# Epoch 60/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9849 - loss: 0.0445 - val_accuracy: 0.7045 - val_loss: 4.6313
# Epoch 61/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0134 - val_accuracy: 0.7045 - val_loss: 4.8704
# Epoch 62/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0125 - val_accuracy: 0.6186 - val_loss: 6.1108
# Epoch 63/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0321 - val_accuracy: 0.6802 - val_loss: 4.4210
# Epoch 64/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9916 - loss: 0.0312 - val_accuracy: 0.5128 - val_loss: 5.2622
# Epoch 65/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.0209 - val_accuracy: 0.6002 - val_loss: 5.1699
# Epoch 66/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9929 - loss: 0.0228 - val_accuracy: 0.6186 - val_loss: 6.4834
# Epoch 67/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0308 - val_accuracy: 0.6938 - val_loss: 5.4722
# Epoch 68/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.0117 - val_accuracy: 0.7045 - val_loss: 5.3858
# Epoch 69/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0362 - val_accuracy: 0.6802 - val_loss: 6.2223
# Epoch 70/70
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9976 - loss: 0.0087 - val_accuracy: 0.6088 - val_loss: 2.7453
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5920 - loss: 2.8507
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# [[0.67619216]
#  [0.9960887 ]
#  [0.8494156 ]
#  ...
#  [0.00187403]
#  [0.39169976]
#  [0.9998086 ]]
# [[1]
#  [1]
#  [1]
#  ...
#  [0]
#  [0]
#  [1]]
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3944    0
# 3945    1
# 3946    0
# 3947    1
# 3948    0
# Name: label, Length: 3949, dtype: int64
# Test Loss: 2.865802764892578, Test Accuracy: 0.5864775776863098
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.46      0.26      0.33      1556
#            1       0.62      0.80      0.70      2393
#
#     accuracy                           0.59      3949
#    macro avg       0.54      0.53      0.52      3949
# weighted avg       0.56      0.59      0.55      3949
#
#
# Confusion Matrix
# [[ 402 1154]
#  [ 479 1914]]
# Time taken: 60.9420 seconds
